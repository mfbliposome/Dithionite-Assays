# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/haoliu/Documents/GitHub/Dithionite-Assays/notebooks'

# %%
file_path = '../data/Decanoic Assay.xlsx'

# %%
# Read all sheets into a dictionary of DataFrames
dfs = pd.read_excel(file_path, sheet_name=None)
print(dfs.keys())
# Out:
# dict_keys(['80 mg (31 mM)', '87 mg (33 mM)', '104 mg (40 mM)', 'Sheet2'])

# %%
df_1 = dfs["80 mg (31 mM)"]
df_1
# Out:
#     Unnamed: 0  31 Trial 1 31 Trial 2  31 Trial 3          LN 31 Trial 1  \
# 0        time   Intensity    Intensity  Intensity  Natural log (Trial 1)
# 1            1   52.082999      79.803     48.506               3.952839
# 2            2   48.437666   77.849333  46.009333               3.880278
# 3            3   45.079999      75.929  43.689333               3.808439
# 4            4   42.095666   74.096333     41.593               3.739945
# ..         ...         ...         ...        ...                    ...
# 597        597      10.003   20.658666  10.016666               2.302885
# 598        598      10.003   20.663333  10.017333               2.302885
# 599        599    9.998666      20.688     10.021               2.302452
# 600        600    9.981333      20.684     10.016               2.300717
# 601        601    9.949999      20.631      9.991               2.297572
#
#               LN 31 Trial 2          LN 31 Trial 3 Unnamed: 7 Unnamed: 8  \
# ...

# %%
df_2 = dfs["87 mg (33 mM)"]
df_2
# Out:
#     Unnamed: 0  33 Trial 1 33 Trial 2 33 Trial 3         ln 33 Trial 1  \
# 0         Time   Intensity  Intensity  Intensity  Natural Log(Trial 1)
# 1            1     107.294  99.563999  90.448999              4.675573
# 2            2  105.930333  98.596666  90.141666              4.662782
# 3            3  104.740666     97.866     89.741              4.651487
# 4            4     103.615  97.532333  89.283999              4.640682
# ..         ...         ...        ...        ...                   ...
# 597        597   13.279333     30.068  36.311333              2.586209
# 598        598       13.28  30.017333  36.241666              2.586259
# 599        599   13.283666  30.007666  36.243333              2.586535
# 600        600   13.291333      29.98  36.225666              2.587112
# 601        601      13.345       29.9     36.178              2.591142
#
#             ln 33 Trial 2         ln 33 Trial 3    Average  \
# ...
